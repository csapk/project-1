# %% [markdown]
# # Data Understanding

# %% [markdown]
# **Import Dataset**

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tahun-2020-s1---jumlah-penduduk-berdasarkan-agama.csv")
df
# Out:
#         Kecamatan       Kelurahan  Islam  Kristen  Katolik  Hindu  Budha  \
# 0           Andir         Campaka  16950     1056      234      7     36
# 1           Andir         Ciroyom  17984     1180      495      0    217
# 2           Andir  Dungus Cariang  16619     1467      470     10    200
# 3           Andir          Garuda   9520      787      308      1     83
# 4           Andir     Kebon Jeruk   7329     2878      883      4    530
# ..            ...             ...    ...      ...      ...    ...    ...
# 146  Ujung Berung       Cigending  16142      262      165     25     11
# 147  Ujung Berung    Pasanggrahan  19656      195       46      8      4
# 148  Ujung Berung     Pasir Endah  16199      299      133     32      6
# 149  Ujung Berung       Pasirjati  16785      288       60      4      0
# 150  Ujung Berung      Pasirwangi  16091      255      119      7      1
#
#      Konghucu  Kepercayaan
# 0           0            0
# 1           3            0
# ...

# %%
# formating dataframe supaya semua dataset dapat muncul 

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 3)

# %%
df
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 0               Andir                      Campaka  16950     1056      234
# 1               Andir                      Ciroyom  17984     1180      495
# 2               Andir               Dungus Cariang  16619     1467      470
# 3               Andir                       Garuda   9520      787      308
# 4               Andir                  Kebon Jeruk   7329     2878      883
# 5               Andir                      Maleber  16825     2223      843
# 6            Antapani               Antapani Kidul  23054     1496      677
# 7            Antapani               Antapani Kulon  10280      456      152
# 8            Antapani              Antapani Tengah  21960     1198      474
# 9            Antapani               Antapani Wetan  17406      971      480
# 10          Arcamanik      Cisaranten Bina Harapan  11691      262      104
# ...

# %% [markdown]
# ## Visualisasi Data

# %%
# Input Data Set
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

religion_names = ['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']
total_pengikut = [2291266, 131233, 54362, 1667, 11571, 165, 122] #Data diambil dari df_sum

# Masukan Rumus Bar Chart agar bisa terbentuk grafiknya
plt.figure(figsize=(12,7), dpi = 100)
plt.barh(religion_names, total_pengikut, color='Grey')

plt.title('Total Penduduk Berdasarkan Agama yang Dianut', size= 16)
plt.xlabel('Jumlah Penganut Agama (Juta)', size= 14)
plt.xticks(size=12)
plt.yticks(size=12)

plt.show()

# %%
plt.style.use('seaborn')

plt.figure(figsize=(12,8), dpi = 100)

labels = ['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']
percents = [2291266, 131233, 54362, 1667, 11571, 165, 122]

explode = (0, 0.4, 0.8, 1.2, 1.5, 1.8, 2)
fig1, ax1 = plt. subplots()
ax1.pie(percents, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan analisis data di atas, dapat disimpulkan bahwa jumlah penganut agama di Kota Bandung diurutkan dari yang terbesar adalah Islam, Kristen, Katolik, Budha, Hindu, Konghucu, dan Kepercayaan.

# %% [markdown]
# ## Exploratory Data Analysis Non Graphical

# %% [markdown]
# **Mengetahui Tipe Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Kecamatan    151 non-null    object
#  1   Kelurahan    151 non-null    object
#  2   Islam        151 non-null    int64
#  3   Kristen      151 non-null    int64
#  4   Katolik      151 non-null    int64
#  5   Hindu        151 non-null    int64
#  6   Budha        151 non-null    int64
#  7   Konghucu     151 non-null    int64
#  8   Kepercayaan  151 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 10.7+ KB

# %% [markdown]
# **Mengetahui Missing Value**

# %%
df.isna().sum()
# Out:
# Kecamatan      0
# Kelurahan      0
# Islam          0
# Kristen        0
# Katolik        0
# Hindu          0
# Budha          0
# Konghucu       0
# Kepercayaan    0
# dtype: int64

# %% [markdown]
# **Mengetahui Duplicated Data**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Berdasarkan analisis data di atas, dapat disimpulkan bahwa tidak ada duplicated data di dalam dataset.

# %% [markdown]
# **Filter Rows & Columns dengan Kriteria**

# %%
# mencari Kecamatan yang penganut agama Islam nya >= 20000

df.loc[(df['Islam'] >= 20000), 'Kecamatan']
# Out:
# 6              Antapani
# 8              Antapani
# 11            Arcamanik
# 20      Babakan Ciparay
# 21      Babakan Ciparay
# 23      Babakan Ciparay
# 25      Babakan Ciparay
# 27        Bandung Kidul
# 35        Bandung Kulon
# 40        Bandung Wetan
# 50      Bojongloa Kaler
# 51      Bojongloa Kaler
# 52      Bojongloa Kaler
# 57      Bojongloa Kidul
# 60             Buahbatu
# 62             Buahbatu
# 63             Buahbatu
# 64     Cibeunying Kaler
# 69     Cibeunying Kidul
# 71     Cibeunying Kidul
# 73     Cibeunying Kidul
# 74               Cibiru
# 76               Cibiru
# 80              Cicendo
# 83              Cicendo
# 84              Cidadap
# 92              Coblong
# 95              Coblong
# 96              Coblong
# 102        Kiaracondong
# 106        Kiaracondong
# 114         Mandalajati
# 122           Rancasari
# 125           Rancasari
# 133            Sukajadi
# 135            Sukajadi
# 138            Sukasari
# 140            Sukasari
# ...

# %%
# mencari kelurahan yang penganut agama Islam nya >= 20000 dan penganut agama Konghucu nya <= 10

df.loc[(df['Islam'] >= 20000) & (df['Konghucu'] <= 10), ['Kelurahan']]
# Out:
#             Kelurahan
# 6      Antapani Kidul
# 8     Antapani Tengah
# 11   Cisaranten Kulon
# 20            Babakan
# 21    Babakan Ciparay
# 23    Margahayu Utara
# 25           Sukahaji
# 27         Kujangsari
# 35            Cijerah
# 40          Tamansari
# 50   Babakan Tarogong
# 51             Jamika
# 52               Kopo
# 57         Kebon Lega
# 60            Cijaura
# 62          Margasari
# 63           Sekejati
# 64           Cigadung
# 69            Cikutra
# 71        Pasirlayung
# 73           Sukapada
# 74           Cipadung
# 76           Palasari
# 80          Pajajaran
# 83           Sukaraja
# 84        Ciumbuleuit
# 92               Dago
# 95       Sadangserang
# 96            Sekeloa
# 102       Babakansari
# 106          Sukapura
# 114        Jatihandap
# 122       Cipamokolan
# 125        Munjahlega
# 133           Cipedes
# 135        Sukabungah
# 138       Gegerkalong
# 140          Sarijadi

# %%
baris = (df['Islam'] >= 20000) & (df['Konghucu'] <= 10)
kolom = ['Kecamatan', 'Kelurahan']

df.loc[baris, kolom]
# Out:
#             Kecamatan         Kelurahan
# 6            Antapani    Antapani Kidul
# 8            Antapani   Antapani Tengah
# 11          Arcamanik  Cisaranten Kulon
# 20    Babakan Ciparay           Babakan
# 21    Babakan Ciparay   Babakan Ciparay
# 23    Babakan Ciparay   Margahayu Utara
# 25    Babakan Ciparay          Sukahaji
# 27      Bandung Kidul        Kujangsari
# 35      Bandung Kulon           Cijerah
# 40      Bandung Wetan         Tamansari
# 50    Bojongloa Kaler  Babakan Tarogong
# 51    Bojongloa Kaler            Jamika
# 52    Bojongloa Kaler              Kopo
# 57    Bojongloa Kidul        Kebon Lega
# 60           Buahbatu           Cijaura
# 62           Buahbatu         Margasari
# 63           Buahbatu          Sekejati
# 64   Cibeunying Kaler          Cigadung
# 69   Cibeunying Kidul           Cikutra
# 71   Cibeunying Kidul       Pasirlayung
# 73   Cibeunying Kidul          Sukapada
# 74             Cibiru          Cipadung
# ...

# %% [markdown]
# **Sorting Data**

# %%
# sorting nama Islam

df.sort_values('Islam', ascending = True)
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 39      Bandung Wetan                      Citarum   1213      482      469
# 38      Bandung Wetan                      Cihapit   2488      804      798
# 120       Panyileukan               Cipadung Wetan   3437       16       16
# 15       Astana Anyar                  Karanganyar   3741     1772      676
# 93            Coblong              Lebak Siliwangi   3812      128       46
# 97           Gedebage                   Cimenerang   4018       54       24
# 143     Sumur Bandung                        Braga   4622      740      505
# 112          Lengkong                     Paledang   4710      982      507
# 100          Gedebage                 Rancanumpang   4853      145       24
# 81            Cicendo                    Pamoyanan   5188     1664     1075
# 56    Bojongloa Kidul              Cibaduyut Wetan   5354     1729      870
# ...

# %%
# sorting berdasarkan penganut agama Kristen

df.sort_values(['Kristen'], ascending = True)
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 120       Panyileukan               Cipadung Wetan   3437       16       16
# 97           Gedebage                   Cimenerang   4018       54       24
# 90            Cinambo                    Sukamulya   5424       79       25
# 75             Cibiru                    Cisurupan  13281      102       34
# 93            Coblong              Lebak Siliwangi   3812      128       46
# 77             Cibiru                   Pasir Biru  15686      144       24
# 100          Gedebage                 Rancanumpang   4853      145       24
# 88            Cinambo             Cisaranten Wetan   5804      145       38
# 147      Ujung Berung                 Pasanggrahan  19656      195       46
# 121       Panyileukan                  Mekar Mulya   6950      203      111
# 87            Cinambo             Babakan Penghulu   6976      223       78
# ...

# %% [markdown]
# ## Multivariate Non Graphical EDA

# %% [markdown]
# **Menghitung Statistik Deskriptif pada Data**

# %%
# khusus tipe data numerik

df.describe()
# Out:
#            Islam   Kristen   Katolik    Hindu    Budha  Konghucu  Kepercayaan
# count    151.000   151.000   151.000  151.000  151.000   151.000      151.000
# mean   15173.947   869.093   360.013   11.040   76.629     1.093        0.808
# std     7397.374   605.948   244.184   12.267   92.924     1.838        2.065
# min     1213.000    16.000    16.000    0.000    0.000     0.000        0.000
# 25%     9030.500   455.000   165.500    2.000   15.000     0.000        0.000
# 50%    15628.000   709.000   302.000    7.000   42.000     0.000        0.000
# 75%    20139.500  1199.500   498.500   15.500  111.500     2.000        1.000
# max    38300.000  3347.000  1079.000   69.000  547.000    10.000       13.000

# %%
# khusus tipe data kategorikal

df.describe(include = 'object')
# Out:
#           Kecamatan Kelurahan
# count           151       151
# unique           30       151
# top     Batununggal   Pasteur
# freq              8         1

# %% [markdown]
# **Menghitung Statistik pada setiap Kolom**

# %%
df.mean()
# Out:
# Islam          15173.947
# Kristen          869.093
# Katolik          360.013
# Hindu             11.040
# Budha             76.629
# Konghucu           1.093
# Kepercayaan        0.808
# dtype: float64

# %%
df.sum()
# Out:
# Kecamatan      AndirAndirAndirAndirAndirAndirAntapaniAntapani...
# Kelurahan      CampakaCiroyomDungus CariangGarudaKebon JerukM...
# Islam                                                    2291266
# Kristen                                                   131233
# Katolik                                                    54362
# Hindu                                                       1667
# Budha                                                      11571
# Konghucu                                                     165
# Kepercayaan                                                  122
# dtype: object

# %%
df.median()
# Out:
# Islam          15628.0
# Kristen          709.0
# Katolik          302.0
# Hindu              7.0
# Budha             42.0
# Konghucu           0.0
# Kepercayaan        0.0
# dtype: float64

# %%
df.std()
# Out:
# Islam          7397.374
# Kristen         605.948
# Katolik         244.184
# Hindu            12.267
# Budha            92.924
# Konghucu          1.838
# Kepercayaan       2.065
# dtype: float64

# %%
df.quantile(0.75)
# Out:
# Islam          20139.5
# Kristen         1199.5
# Katolik          498.5
# Hindu             15.5
# Budha            111.5
# Konghucu           2.0
# Kepercayaan        1.0
# Name: 0.75, dtype: float64

# %% [markdown]
# # Data Preparation

# %% [markdown]
# **Mendeteksi Outlier Menggunakan Rumus Tukey's Fences IQR (Spread)**

# %%
q1 = df.quantile(0.25) # minimum
q3 = df.quantile(0.75) # maximum
iqr = q3 - q1
iqr
# Out:
# Islam          11109.0
# Kristen          744.5
# Katolik          333.0
# Hindu             13.5
# Budha             96.5
# Konghucu           2.0
# Kepercayaan        1.0
# dtype: float64

# %%
outlier_criteria = (df < (q1-1.5*iqr)) | (df > (q3+1.5*iqr))
outlier_criteria
# Out:
# <ipython-input-23-73b770a3c2de>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (df < (q1-1.5*iqr)) | (df > (q3+1.5*iqr))
# <ipython-input-23-73b770a3c2de>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (df < (q1-1.5*iqr)) | (df > (q3+1.5*iqr))
#      Budha  Hindu  Islam  Katolik  Kecamatan  Kelurahan  Kepercayaan  \
# 0    False  False  False    False      False      False        False
# 1    False  False  False    False      False      False        False
# 2    False  False  False    False      False      False        False
# 3    False  False  False    False      False      False         True
# ...

# %%
outlier_criteria.sum()
# Out:
# Budha           5
# Hindu           9
# Islam           2
# Katolik         2
# Kecamatan       0
# Kelurahan       0
# Kepercayaan    15
# Konghucu        5
# Kristen         3
# dtype: int64

# %% [markdown]
# Berdasarkan analisis data di atas, dapat disimpulkan bahwa variabel outlier ditemukan di semua variabel, kecuali Kecamatan dan Kelurahan.

# %%
# data yang outlier 

df_outlier = df[outlier_criteria.any(axis=1)]
df_outlier
# Out:
#             Kecamatan         Kelurahan  Islam  Kristen  Katolik  Hindu  \
# 3               Andir            Garuda   9520      787      308      1
# 4               Andir       Kebon Jeruk   7329     2878      883      4
# 6            Antapani    Antapani Kidul  23054     1496      677     51
# 13          Arcamanik        Sukamiskin  19523     1371      653     52
# 14       Astana Anyar           Cibadak   8916     3347      693      5
# 15       Astana Anyar       Karanganyar   3741     1772      676      8
# 22    Babakan Ciparay        Cirangrang  10500      570      218      0
# 25    Babakan Ciparay          Sukahaji  27353     2249      725      2
# 28      Bandung Kidul           Mengger   8414     1260     1079     29
# 50    Bojongloa Kaler  Babakan Tarogong  26944     1614      298      0
# 51    Bojongloa Kaler            Jamika  23563     3267      683      5
# 52    Bojongloa Kaler              Kopo  28741     1498      461      8
# ...

# %%
# data yang tidak outlier 

df_no_outlier = df[~outlier_criteria.any(axis=1)]
df_no_outlier
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 0               Andir                      Campaka  16950     1056      234
# 1               Andir                      Ciroyom  17984     1180      495
# 2               Andir               Dungus Cariang  16619     1467      470
# 5               Andir                      Maleber  16825     2223      843
# 7            Antapani               Antapani Kulon  10280      456      152
# 8            Antapani              Antapani Tengah  21960     1198      474
# 9            Antapani               Antapani Wetan  17406      971      480
# 10          Arcamanik      Cisaranten Bina Harapan  11691      262      104
# 11          Arcamanik             Cisaranten Kulon  22596      719      249
# 12          Arcamanik  Sindanglaya/Cisantren Endah  18262      869      445
# 16       Astana Anyar                      Karasak  11597     1337      550
# ...

# %%
# memfilter Kelurahan dan jumlah penganut agama Kepercayaan yang termasuk dalam outlier

df.loc[:, ['Kelurahan', 'Kepercayaan']][outlier_criteria['Kepercayaan']].sort_values(by = ['Kepercayaan'], ascending = False)
# Out:
#           Kelurahan  Kepercayaan
# 60          Cijaura           13
# 148     Pasir Endah           10
# 3            Garuda            9
# 142  Babakan Ciamis            9
# 124      Mekarmulya            8
# 114      Jatihandap            7
# 52             Kopo            6
# 92             Dago            5
# 130       Ciseureuh            5
# 22       Cirangrang            4
# 118  Cipadung Kidul            4
# 71      Pasirlayung            3
# 131       Pasirluyu            3
# 138     Gegerkalong            3
# 140        Sarijadi            3

# %%
#Input Dataset
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

mobile = pd.read_csv('tahun-2020-s1---jumlah-penduduk-berdasarkan-agama.csv')
mobile.head()
# Out:
#   Kecamatan       Kelurahan  Islam  Kristen  Katolik  Hindu  Budha  Konghucu  \
# 0     Andir         Campaka  16950     1056      234      7     36         0
# 1     Andir         Ciroyom  17984     1180      495      0    217         3
# 2     Andir  Dungus Cariang  16619     1467      470     10    200         1
# 3     Andir          Garuda   9520      787      308      1     83         1
# 4     Andir     Kebon Jeruk   7329     2878      883      4    530         0
#
#    Kepercayaan
# 0            0
# 1            0
# 2            0
# 3            9
# 4            0

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Kecamatan    151 non-null    object
#  1   Kelurahan    151 non-null    object
#  2   Islam        151 non-null    int64
#  3   Kristen      151 non-null    int64
#  4   Katolik      151 non-null    int64
#  5   Hindu        151 non-null    int64
#  6   Budha        151 non-null    int64
#  7   Konghucu     151 non-null    int64
#  8   Kepercayaan  151 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 10.7+ KB

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Handling Outlier

# %%
Data = pd.read_csv("tahun-2020-s1---jumlah-penduduk-berdasarkan-agama.csv")
Data.describe()
# Out:
#            Islam   Kristen   Katolik    Hindu    Budha  Konghucu  Kepercayaan
# count    151.000   151.000   151.000  151.000  151.000   151.000      151.000
# mean   15173.947   869.093   360.013   11.040   76.629     1.093        0.808
# std     7397.374   605.948   244.184   12.267   92.924     1.838        2.065
# min     1213.000    16.000    16.000    0.000    0.000     0.000        0.000
# 25%     9030.500   455.000   165.500    2.000   15.000     0.000        0.000
# 50%    15628.000   709.000   302.000    7.000   42.000     0.000        0.000
# 75%    20139.500  1199.500   498.500   15.500  111.500     2.000        1.000
# max    38300.000  3347.000  1079.000   69.000  547.000    10.000       13.000

# %% [markdown]
# **IQR Method Detection**

# %%
q1 = Data.quantile(0.25) # minimum
q3 = Data.quantile(0.75) # maximum
iqr = q3 - q1

outlier_criteria = (Data< (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))
outlier_criteria.sum()
# Out:
# <ipython-input-31-de2739df3d4b>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (Data< (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))
# <ipython-input-31-de2739df3d4b>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (Data< (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))
# Budha           5
# Hindu           9
# Islam           2
# Katolik         2
# Kecamatan       0
# Kelurahan       0
# Kepercayaan    15
# Konghucu        5
# Kristen         3
# dtype: int64

# %% [markdown]
# Berdasarkan metode di atas, dapat disimpulkan bahwa terdapat outlier pada data.

# %% [markdown]
# **Histogram**

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.distplot(Data.Budha)
plt.subplot(2,2,2)
sns.distplot(Data.Hindu)
plt.subplot(2,2,3)
sns.distplot(Data.Islam)
plt.subplot(2,2,4)
sns.distplot(Data.Kepercayaan)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.distplot(Data.Katolik)
plt.subplot(2,2,2)
sns.distplot(Data.Konghucu)
plt.subplot(2,2,3)
sns.distplot(Data.Kristen)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Boxplot**

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.boxplot(Data.Budha)
plt.subplot(2,2,2)
sns.boxplot(Data.Hindu)
plt.subplot(2,2,3)
sns.boxplot(Data.Islam)
plt.subplot(2,2,4)
sns.boxplot(Data.Kepercayaan)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.boxplot(Data.Katolik)
plt.subplot(2,2,2)
sns.boxplot(Data.Konghucu)
plt.subplot(2,2,3)
sns.boxplot(Data.Kristen)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Remove Outlier

# %%
Data_out = Data[~((Data < (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))).any(axis=1)]
Data_out.shape
# Out:
# <ipython-input-36-cb400a96b2ae>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   Data_out = Data[~((Data < (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))).any(axis=1)]
# <ipython-input-36-cb400a96b2ae>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   Data_out = Data[~((Data < (q1-1.5*iqr)) | (Data > (q3+1.5*iqr))).any(axis=1)]
# (117, 9)

# %% [markdown]
# **Mendeteksi Outlier**

# %%
q1 = Data.quantile(0.25) # minimum
q3 = Data.quantile(0.75) # maximum
iqr = q3 - q1

outlier_criteria = (Data_out < (q1-1.5*iqr)) | (Data_out > (q3+1.5*iqr))
outlier_criteria.sum()
# Out:
# <ipython-input-37-b19bf22bcfdf>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (Data_out < (q1-1.5*iqr)) | (Data_out > (q3+1.5*iqr))
# <ipython-input-37-b19bf22bcfdf>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outlier_criteria = (Data_out < (q1-1.5*iqr)) | (Data_out > (q3+1.5*iqr))
# Budha          0
# Hindu          0
# Islam          0
# Katolik        0
# Kecamatan      0
# Kelurahan      0
# Kepercayaan    0
# Konghucu       0
# Kristen        0
# dtype: int64

# %% [markdown]
# Berdasarkan metode di atas, dapat disimpulkan bahwa outlier dalam data telah dihilangkan.

# %%
Data_out.sum()
# Out:
# Kecamatan      AndirAndirAndirAndirAntapaniAntapaniAntapaniAr...
# Kelurahan      CampakaCiroyomDungus CariangMaleberAntapani Ku...
# Islam                                                    1702843
# Kristen                                                    90389
# Katolik                                                    38314
# Hindu                                                       1029
# Budha                                                       7649
# Konghucu                                                     109
# Kepercayaan                                                   24
# dtype: object

# %%
Data_out.describe()
# Out:
#            Islam   Kristen  Katolik    Hindu    Budha  Konghucu  Kepercayaan
# count    117.000   117.000  117.000  117.000  117.000   117.000      117.000
# mean   14554.214   772.556  327.470    8.795   65.376     0.932        0.205
# std     6485.951   497.838  228.408    8.585   67.762     1.490        0.483
# min     1213.000    16.000   16.000    0.000    0.000     0.000        0.000
# 25%     9485.000   430.000  152.000    2.000   12.000     0.000        0.000
# 50%    15456.000   662.000  272.000    7.000   36.000     0.000        0.000
# 75%    18862.000  1063.000  472.000   14.000  102.000     2.000        0.000
# max    30873.000  2298.000  931.000   35.000  242.000     5.000        2.000

# %% [markdown]
# **Histogram**

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.distplot(Data_out.Budha)
plt.subplot(2,2,2)
sns.distplot(Data_out.Hindu)
plt.subplot(2,2,3)
sns.distplot(Data_out.Islam)
plt.subplot(2,2,4)
sns.distplot(Data_out.Kepercayaan)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.distplot(Data_out.Katolik)
plt.subplot(2,2,2)
sns.distplot(Data_out.Konghucu)
plt.subplot(2,2,3)
sns.distplot(Data_out.Kristen)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Boxplot**

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.boxplot(Data_out.Budha)
plt.subplot(2,2,2)
sns.boxplot(Data_out.Hindu)
plt.subplot(2,2,3)
sns.boxplot(Data_out.Islam)
plt.subplot(2,2,4)
sns.boxplot(Data_out.Kepercayaan)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.boxplot(Data_out.Katolik)
plt.subplot(2,2,2)
sns.boxplot(Data_out.Konghucu)
plt.subplot(2,2,3)
sns.boxplot(Data_out.Kristen)
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Trio 3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Korelasi Data

# %%
Data_out.corr()
# Out:
#              Islam  Kristen  Katolik  Hindu  Budha  Konghucu  Kepercayaan
# Islam        1.000    0.198    0.126  0.286 -0.143    -0.096       -0.003
# Kristen      0.198    1.000    0.857  0.053  0.822     0.409        0.080
# Katolik      0.126    0.857    1.000  0.160  0.697     0.430        0.081
# Hindu        0.286    0.053    0.160  1.000 -0.173    -0.019        0.071
# Budha       -0.143    0.822    0.697 -0.173  1.000     0.480        0.074
# Konghucu    -0.096    0.409    0.430 -0.019  0.480     1.000        0.080
# Kepercayaan -0.003    0.080    0.081  0.071  0.074     0.080        1.000

# %% [markdown]
# Interpretasi : semakin tinggi nilai korelasi, maka dapat dikatakan sebagai hubungan yang semakin kuat
# > - -1 = hubungan yang berkebalikan
# > - 0 = tidak ada hubungan
# > - +1 = ada hubungan

# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## K-Means Clustering

# %%
import pandas as pd
import numpy as np 

import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

# %%
# import data 

df = Data_out
df.head(5)
# Out:
#   Kecamatan       Kelurahan  Islam  Kristen  Katolik  Hindu  Budha  Konghucu  \
# 0     Andir         Campaka  16950     1056      234      7     36         0
# 1     Andir         Ciroyom  17984     1180      495      0    217         3
# 2     Andir  Dungus Cariang  16619     1467      470     10    200         1
# 5     Andir         Maleber  16825     2223      843     28    194         3
# 7  Antapani  Antapani Kulon  10280      456      152      7     18         0
#
#    Kepercayaan
# 0            0
# 1            0
# 2            0
# 5            0
# 7            0

# %%
# check data types 

Data_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 150
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Kecamatan    117 non-null    object
#  1   Kelurahan    117 non-null    object
#  2   Islam        117 non-null    int64
#  3   Kristen      117 non-null    int64
#  4   Katolik      117 non-null    int64
#  5   Hindu        117 non-null    int64
#  6   Budha        117 non-null    int64
#  7   Konghucu     117 non-null    int64
#  8   Kepercayaan  117 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 9.1+ KB

# %%
# copy data 

mall = Data_out

# %%
# descriptive statistics untuk mengetahui distribusi data

mall.describe()
# Out:
#            Islam   Kristen  Katolik    Hindu    Budha  Konghucu  Kepercayaan
# count    117.000   117.000  117.000  117.000  117.000   117.000      117.000
# mean   14554.214   772.556  327.470    8.795   65.376     0.932        0.205
# std     6485.951   497.838  228.408    8.585   67.762     1.490        0.483
# min     1213.000    16.000   16.000    0.000    0.000     0.000        0.000
# 25%     9485.000   430.000  152.000    2.000   12.000     0.000        0.000
# 50%    15456.000   662.000  272.000    7.000   36.000     0.000        0.000
# 75%    18862.000  1063.000  472.000   14.000  102.000     2.000        0.000
# max    30873.000  2298.000  931.000   35.000  242.000     5.000        2.000

# %%
# define category and numeric

nums = mall[['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']]
cat = mall[['Kecamatan']]

# %%
cat
# Out:
#             Kecamatan
# 0               Andir
# 1               Andir
# 2               Andir
# 5               Andir
# 7            Antapani
# 8            Antapani
# 9            Antapani
# 10          Arcamanik
# 11          Arcamanik
# 12          Arcamanik
# 16       Astana Anyar
# 17       Astana Anyar
# 18       Astana Anyar
# 19       Astana Anyar
# 20    Babakan Ciparay
# 21    Babakan Ciparay
# 23    Babakan Ciparay
# 24    Babakan Ciparay
# 26      Bandung Kidul
# 27      Bandung Kidul
# 29      Bandung Kidul
# 30      Bandung Kulon
# 31      Bandung Kulon
# 32      Bandung Kulon
# 33      Bandung Kulon
# 34      Bandung Kulon
# 35      Bandung Kulon
# 36      Bandung Kulon
# 37      Bandung Kulon
# 38      Bandung Wetan
# 39      Bandung Wetan
# 40      Bandung Wetan
# 41        Batununggal
# 42        Batununggal
# 43        Batununggal
# 44        Batununggal
# 45        Batununggal
# 46        Batununggal
# 47        Batununggal
# 48        Batununggal
# ...

# %%
nums
# Out:
#      Islam  Kristen  Katolik  Hindu  Budha  Konghucu  Kepercayaan
# 0    16950     1056      234      7     36         0            0
# 1    17984     1180      495      0    217         3            0
# 2    16619     1467      470     10    200         1            0
# 5    16825     2223      843     28    194         3            0
# 7    10280      456      152      7     18         0            0
# 8    21960     1198      474     25     22         1            1
# 9    17406      971      480     14     25         0            1
# 10   11691      262      104      8      2         0            0
# 11   22596      719      249     20     20         0            0
# 12   18262      869      445     31     15         0            0
# 16   11597     1337      550      9    151         4            2
# 17   10473     1201      325      6    242         1            0
# 18    6280      928      249      0    174         0            0
# ...

# %%
mall
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 0               Andir                      Campaka  16950     1056      234
# 1               Andir                      Ciroyom  17984     1180      495
# 2               Andir               Dungus Cariang  16619     1467      470
# 5               Andir                      Maleber  16825     2223      843
# 7            Antapani               Antapani Kulon  10280      456      152
# 8            Antapani              Antapani Tengah  21960     1198      474
# 9            Antapani               Antapani Wetan  17406      971      480
# 10          Arcamanik      Cisaranten Bina Harapan  11691      262      104
# 11          Arcamanik             Cisaranten Kulon  22596      719      249
# 12          Arcamanik  Sindanglaya/Cisantren Endah  18262      869      445
# 16       Astana Anyar                      Karasak  11597     1337      550
# ...

# %%
# Optimasi K-Means dengan metode elbow untuk menentukan jumlah klaster yang tepat
from sklearn.cluster import KMeans 
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42) 
    kmeans.fit(nums)
    wcss.append(kmeans.inertia_) 

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Cluster Number')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\Trio 3\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# Berdasarkan metode elbow, grafik berbentuk elbow terdapat pada cluster 2 dan 3, maka dapat disimpulkan pembagian klaster 2 atau 3 adalah yang paling optimum.

# %%
# Proses K-Means Clustering
km_elbow = KMeans(n_clusters = 3, 
                     init = 'k-means++', 
                     max_iter = 100, 
                     n_init = 10, 
                     random_state = 42)
y_kmeans = km_elbow.fit_predict(nums.values)

# %%
# concate dengan dataframe hasil copy tadi, yaitu mall

mall['Cluster'] = y_kmeans
# Out:
# <ipython-input-56-51f694b4853c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mall['Cluster'] = y_kmeans

# %%
mall.head()
# Out:
#   Kecamatan       Kelurahan  Islam  Kristen  Katolik  Hindu  Budha  Konghucu  \
# 0     Andir         Campaka  16950     1056      234      7     36         0
# 1     Andir         Ciroyom  17984     1180      495      0    217         3
# 2     Andir  Dungus Cariang  16619     1467      470     10    200         1
# 5     Andir         Maleber  16825     2223      843     28    194         3
# 7  Antapani  Antapani Kulon  10280      456      152      7     18         0
#
#    Kepercayaan  Cluster
# 0            0        2
# 1            0        2
# 2            0        2
# 5            0        2
# 7            0        0

# %%
average = mall.groupby(['Cluster'], as_index = False).mean()
average
# Out:
#    Cluster      Islam  Kristen  Katolik   Hindu   Budha  Konghucu  Kepercayaan
# 0        0   8064.957  715.043  322.596   5.362  80.617     1.085        0.234
# 1        1  23600.208  909.125  386.083  12.292  48.250     0.708        0.167
# 2        2  16464.891  760.065  301.870  10.478  58.739     0.891        0.196

# %% [markdown]
# Tabel di atas menunjukkan cluster beserta rata-rata jumlah penganut agama.

# %%
features = ['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']

# %%
list(enumerate(features))
# Out:
# [(0, 'Islam'),
#  (1, 'Kristen'),
#  (2, 'Katolik'),
#  (3, 'Hindu'),
#  (4, 'Budha'),
#  (5, 'Konghucu'),
#  (6, 'Kepercayaan')]

# %%
plt.figure(figsize = (12,5))
for i in enumerate(features):
    plt.subplot(2, 7, i[0]+1) # (rows, columns, index figure)
    sns.barplot(x = 'Cluster', y = i[1], data = average, ci = None)
    plt.tight_layout();

# %% [markdown]
# ## Interpretasi
# - Islam: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Kristen: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Katolik: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 2.
# - Hindu: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Budha: Jumlah penganut paling banyak terdapat pada cluster 0, sedangkan jumlah paling sedikit terdapat pada cluster 1.
# - Konghucu: Jumlah penganut paling banyak terdapat pada cluster 0, sedangkan jumlah paling sedikit terdapat pada cluster 1.
# - Kepercayaan: Jumlah penganut paling banyak terdapat pada cluster 0, sedangkan jumlah paling sedikit terdapat pada cluster 1.

# %%
# deep dive 

grouping = pd.DataFrame(mall.groupby(['Cluster', 'Kecamatan']).Kecamatan.count())
grouping
# Out:
#                           Kecamatan
# Cluster Kecamatan
# 0       Antapani                  1
#         Arcamanik                 1
#         Astana Anyar              3
#         Babakan Ciparay           1
#         Bandung Kidul             1
#         Bandung Kulon             3
#         Bandung Wetan             2
#         Batununggal               2
#         Bojongloa Kidul           3
#         Buahbatu                  1
#         Cibeunying Kaler          2
#         Cibeunying Kidul          1
#         Cicendo                   2
#         Cidadap                   1
#         Cinambo                   3
#         Coblong                   3
#         Gedebage                  3
#         Kiaracondong              1
#         Lengkong                  5
#         Panyileukan               2
#         Regol                     4
#         Sukasari                  1
#         Sumur Bandung             1
# 1       Antapani                  1
# ...

# %% [markdown]
# **Visualisasi Data**

# %%
from sklearn.decomposition import PCA

# %%
mall
# Out:
#             Kecamatan                    Kelurahan  Islam  Kristen  Katolik  \
# 0               Andir                      Campaka  16950     1056      234
# 1               Andir                      Ciroyom  17984     1180      495
# 2               Andir               Dungus Cariang  16619     1467      470
# 5               Andir                      Maleber  16825     2223      843
# 7            Antapani               Antapani Kulon  10280      456      152
# 8            Antapani              Antapani Tengah  21960     1198      474
# 9            Antapani               Antapani Wetan  17406      971      480
# 10          Arcamanik      Cisaranten Bina Harapan  11691      262      104
# 11          Arcamanik             Cisaranten Kulon  22596      719      249
# 12          Arcamanik  Sindanglaya/Cisantren Endah  18262      869      445
# 16       Astana Anyar                      Karasak  11597     1337      550
# ...

# %%
# definisikan fungsi pca

pca = PCA(n_components = 2)

# %%
# bagi data menjadi feature dan target (X dan Y)

X_pca = mall[['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']]
Y_pca = mall[['Cluster']]

# %%
X_pca
# Out:
#      Islam  Kristen  Katolik  Hindu  Budha  Konghucu  Kepercayaan
# 0    16950     1056      234      7     36         0            0
# 1    17984     1180      495      0    217         3            0
# 2    16619     1467      470     10    200         1            0
# 5    16825     2223      843     28    194         3            0
# 7    10280      456      152      7     18         0            0
# 8    21960     1198      474     25     22         1            1
# 9    17406      971      480     14     25         0            1
# 10   11691      262      104      8      2         0            0
# 11   22596      719      249     20     20         0            0
# 12   18262      869      445     31     15         0            0
# 16   11597     1337      550      9    151         4            2
# 17   10473     1201      325      6    242         1            0
# 18    6280      928      249      0    174         0            0
# ...

# %%
Y_pca
# Out:
#      Cluster
# 0          2
# 1          2
# 2          2
# 5          2
# 7          0
# 8          1
# 9          2
# 10         0
# 11         1
# 12         2
# 16         0
# 17         0
# 18         0
# 19         2
# 20         1
# 21         1
# 23         1
# 24         0
# 26         2
# 27         1
# 29         0
# 30         0
# 31         2
# 32         2
# 33         0
# 34         0
# 35         1
# 36         2
# 37         2
# 38         0
# 39         0
# 40         1
# 41         2
# 42         2
# 43         2
# 44         0
# 45         0
# 46         2
# 47         2
# 48         2
# 49         2
# 53         2
# 54         0
# 55         0
# 56         0
# 57         1
# 59         2
# 61         0
# 63         1
# 64         1
# 65         0
# 66         0
# 67         2
# 68         2
# 69         1
# 70         2
# 72         0
# 73         1
# 74         1
# 75         2
# 76         1
# 77         2
# 78         0
# 79         2
# 80         1
# ...

# %%
principal = pca.fit_transform(X_pca)
principal
# Out:
# array([[ 2.39944569e+03,  1.83484942e+02],
#        [ 3.43610999e+03,  4.01020314e+02],
#        [ 2.07559989e+03,  6.74036091e+02],
#        [ 2.29484117e+03,  1.50627040e+03],
#        [-4.27923003e+03, -2.96031548e+02],
#        [ 7.41207868e+03,  3.25915684e+02],
#        [ 2.85520441e+03,  1.91439400e+02],
#        [-2.87157454e+03, -5.16091769e+02],
#        [ 8.03965219e+03, -2.09643973e+02],
#        [ 3.70939619e+03,  7.00460275e+01],
#        [-2.94731627e+03,  6.58417027e+02],
#        [-4.07439798e+03,  4.75109096e+02],
#        [-8.27128342e+03,  2.53570926e+02],
#        [ 3.85097864e+03,  5.53511777e+02],
#        [ 1.28669164e+04,  9.49456029e+02],
#        [ 1.63276610e+04,  4.30015000e+02],
#        [ 6.06126385e+03,  3.52128469e+02],
#        [-3.50489350e+03, -1.50592249e+02],
#        [ 3.12964138e+03,  1.20358654e+02],
#        [ 6.69648408e+03, -4.62107667e+02],
#        [-6.81981319e+03, -4.42292595e+02],
#        [-6.41219414e+03,  1.69764988e+02],
# ...

# %%
print(f'Explained variance ratio from PCA: {pca.explained_variance_ratio_}')
# Out:
# Explained variance ratio from PCA: [0.99306314 0.00663144]

# %%
df_principal = pd.DataFrame(data = principal, columns = ['principal component 1', 'principal component 2'])
df_principal
# Out:
#      principal component 1  principal component 2
# 0                 2399.446                183.485
# 1                 3436.110                401.020
# 2                 2075.600                674.036
# 3                 2294.841               1506.270
# 4                -4279.230               -296.032
# 5                 7412.079                325.916
# 6                 2855.204                191.439
# 7                -2871.575               -516.092
# 8                 8039.652               -209.644
# 9                 3709.396                 70.046
# 10               -2947.316                658.417
# 11               -4074.398                475.109
# 12               -8271.283                253.571
# 13                3850.979                553.512
# 14               12866.916                949.456
# 15               16327.661                430.015
# 16                6061.264                352.128
# 17               -3504.894               -150.592
# ...

# %%
# menggabungkan hasil cluster dg data frame pca 
df_principal.reset_index(drop=True, inplace=True)
Y_pca.reset_index(drop=True, inplace=True)

finaldf = df_principal.join(Y_pca)
finaldf
# Out:
#      principal component 1  principal component 2  Cluster
# 0                 2399.446                183.485        2
# 1                 3436.110                401.020        2
# 2                 2075.600                674.036        2
# 3                 2294.841               1506.270        2
# 4                -4279.230               -296.032        0
# 5                 7412.079                325.916        1
# 6                 2855.204                191.439        2
# 7                -2871.575               -516.092        0
# 8                 8039.652               -209.644        1
# 9                 3709.396                 70.046        2
# 10               -2947.316                658.417        0
# 11               -4074.398                475.109        0
# 12               -8271.283                253.571        0
# 13                3850.979                553.512        2
# 14               12866.916                949.456        1
# ...

# %%
# starts visualizing 

plt.figure(figsize = (8,5))

plt.title('Clustering Results', size = 20)
sns.scatterplot(x = 'principal component 1', 
                y = 'principal component 2', 
                hue = 'Cluster', 
                data = finaldf, 
               palette = 'plasma')

plt.grid(alpha = 0.5)
plt.tight_layout();

# %% [markdown]
# Dengan menggunakan metode K-Means clustering, dihasilkan scatterplot seperti di atas, dimana data dikelompokkan menjadi 3 cluster.

# %% [markdown]
# ## Hierarchical Clustering

# %%
# Menggunakan dendrogram untuk menentukan angka cluster yang tepat
import scipy.cluster.hierarchy as sch

# %%
nums.head()
# Out:
#    Islam  Kristen  Katolik  Hindu  Budha  Konghucu  Kepercayaan
# 0  16950     1056      234      7     36         0            0
# 1  17984     1180      495      0    217         3            0
# 2  16619     1467      470     10    200         1            0
# 5  16825     2223      843     28    194         3            0
# 7  10280      456      152      7     18         0            0

# %%
plt.figure(figsize = (12,8))
dendrogram = sch.dendrogram(sch.linkage(nums.values, method = 'ward'))

plt.title('Dendrogram', size = 20)
plt.xlabel('Penganut Agama')
plt.ylabel('Euclidean distances');

# %% [markdown]
# Dengan mengambil titik tengah di 30000, maka jumlah cluster yang optimum adalah 3 cluster.

# %%
# Menjalankan Hierarchical Clustering ke dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(nums)

# %% [markdown]
# **Visualisasi Data**

# %%
df_hc = df.copy()

# %%
df_hc['Cluster'] = y_hc

# %%
df_hc.head()
# Out:
#   Kecamatan       Kelurahan  Islam  Kristen  Katolik  Hindu  Budha  Konghucu  \
# 0     Andir         Campaka  16950     1056      234      7     36         0
# 1     Andir         Ciroyom  17984     1180      495      0    217         3
# 2     Andir  Dungus Cariang  16619     1467      470     10    200         1
# 5     Andir         Maleber  16825     2223      843     28    194         3
# 7  Antapani  Antapani Kulon  10280      456      152      7     18         0
#
#    Kepercayaan  Cluster
# 0            0        2
# 1            0        2
# 2            0        2
# 5            0        2
# 7            0        0

# %%
averaging = df_hc.groupby('Cluster', as_index = False).mean()
averaging
# Out:
#    Cluster      Islam  Kristen  Katolik   Hindu   Budha  Konghucu  Kepercayaan
# 0        0   8968.877  660.333  299.123   6.404  70.246     1.018        0.193
# 1        1  23600.208  909.125  386.083  12.292  48.250     0.708        0.167
# 2        2  17367.000  859.194  333.278  10.250  69.083     0.944        0.250

# %%
plt.figure(figsize = (12,5))
for i in enumerate(features):
    plt.subplot(2, 7, i[0]+1)
    sns.barplot(x = 'Cluster', y = i[1], data = averaging, ci = None)
    plt.tight_layout()

# %% [markdown]
# ## Interpretasi
# - Islam: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Kristen: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Katolik: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Hindu: Jumlah penganut paling banyak terdapat pada cluster 1, sedangkan jumlah paling sedikit terdapat pada cluster 0.
# - Budha: Jumlah penganut paling banyak terdapat pada cluster 0, sedangkan jumlah paling sedikit terdapat pada cluster 1.
# - Konghucu: Jumlah penganut paling banyak terdapat pada cluster 0, sedangkan jumlah paling sedikit terdapat pada cluster 1.
# - Kepercayaan: Jumlah penganut paling banyak terdapat pada cluster 2, sedangkan jumlah paling sedikit terdapat pada cluster 1.

# %%
# deep dive 

grouped = pd.DataFrame(df_hc.groupby(['Cluster', 'Kecamatan']).Kecamatan.count())
grouped
# Out:
#                           Kecamatan
# Cluster Kecamatan
# 0       Antapani                  1
#         Arcamanik                 1
#         Astana Anyar              3
#         Babakan Ciparay           1
#         Bandung Kidul             1
#         Bandung Kulon             3
#         Bandung Wetan             2
#         Batununggal               4
#         Bojongloa Kidul           3
#         Buahbatu                  1
#         Cibeunying Kaler          2
#         Cibeunying Kidul          1
#         Cibiru                    1
#         Cicendo                   2
#         Cidadap                   1
#         Cinambo                   3
#         Coblong                   3
#         Gedebage                  3
#         Kiaracondong              2
#         Lengkong                  6
#         Mandalajati               2
#         Panyileukan               3
#         Regol                     4
#         Sukajadi                  1
# ...

# %% [markdown]
# **Visualisasi Cluster**

# %%
nums.head()
# Out:
#    Islam  Kristen  Katolik  Hindu  Budha  Konghucu  Kepercayaan
# 0  16950     1056      234      7     36         0            0
# 1  17984     1180      495      0    217         3            0
# 2  16619     1467      470     10    200         1            0
# 5  16825     2223      843     28    194         3            0
# 7  10280      456      152      7     18         0            0

# %%
pca_hc = PCA(n_components = 2)

# %%
# pecah antara feature & target 

X_pca_hc = nums[['Islam', 'Kristen', 'Katolik', 'Hindu', 'Budha', 'Konghucu', 'Kepercayaan']]
Y_pca_hc = y_hc

# %%
principal_hc = pca_hc.fit_transform(X_pca_hc)

# %%
print(f'Explained variance ratio from PCA: {pca_hc.explained_variance_ratio_}')
# Out:
# Explained variance ratio from PCA: [0.99306314 0.00663144]

# %%
df_pca_hc = pd.DataFrame(data = principal_hc, 
                        columns = ['pc 1', 'pc 2'])
df_pca_hc.head()
# Out:
#        pc 1      pc 2
# 0  2399.446   183.485
# 1  3436.110   401.020
# 2  2075.600   674.036
# 3  2294.841  1506.270
# 4 -4279.230  -296.032

# %%
finalhc = df_pca_hc.join(df_hc['Cluster'])
finalhc.head()
# Out:
#        pc 1      pc 2  Cluster
# 0  2399.446   183.485      2.0
# 1  3436.110   401.020      2.0
# 2  2075.600   674.036      2.0
# 3  2294.841  1506.270      NaN
# 4 -4279.230  -296.032      NaN

# %%
plt.figure(figsize = (8,5))

plt.title('Clustering Results', size = 20)
sns.scatterplot(x = 'pc 1', 
                y = 'pc 2', 
                hue = 'Cluster', 
                data = finalhc, 
               palette = 'rainbow_r')

plt.grid(alpha = 0.5)
plt.tight_layout();

# %% [markdown]
# Dengan menggunakan metode Hierarchical clustering, dihasilkan scatterplot seperti di atas, dimana data dikelompokkan menjadi 3 cluster.

# %% [markdown]
# ## Hasil Perbandingan

# %% [markdown]
# Dilakukan analisis terhadap scatterplot hasil dari metode K-Means Clustering dan scatterplot hasil dari metode Hierarchical Clustering. Berdasarkan analisis tersebut, diperoleh bahwa penggunaan metode K-Means Clustering lebih sesuai dibandingkan penggunaan metode Hierarchical Clustering. Hal ini dikarenakan hasil clustering dari metode K-Means menunjukkan pembagian objek data ke dalam kelompok tidak saling overlap, sehingga setiap data berada tepat di satu cluster. Sedangkan hasil clustering dari metode Hierarchical kelompok datanya saling overlap dan tidak tepat di satu cluster.

# %% [markdown]
# # Evaluation

# %% [markdown]
# Berdasarkan hasil dari metode K-Means Clustering, dapat disimpulkan bahwa data terbagi menjadi 3 cluster berdasarkan jumlah penganut agamanya. Cluster tersebut memiliki rincian data sebagai berikut:
# - Cluster 0 memiliki rata-rata penganut agama Islam sebesar 8064.957, Kristen sebesar 715.043, Katolik sebesar 322.596, Hindu sebesar 5.362, Budha sebesar 80.617, Konghucu sebesar 1.085, dan Kepercayaan sebesar 0.234.
# - Cluster 1 memiliki rata-rata penganut agama Islam sebesar 23600.208, Kristen sebesar 909.125, Katolik sebesar 386.083, Hindu sebesar 12.292, Budha sebesar 48.25, Konghucu sebesar 0.708, dan Kepercayaan sebesar 0.167.
# - Cluster 2 memiliki rata-rata penganut agama Islam sebesar 16464.891, Kristen sebesar 760.065, Katolik sebesar 301.87, Hindu sebesar 10.478, Budha sebesar 58.739, Konghucu sebesar 0.891, dan Kepercayaan sebesar 0.196.
#
# Berdasarkan Rata-rata Jumlah Penganut Agamanya:
# - Penganut agama Islam paling banyak berada di cluster 1 dan paling sedikit berada di cluster 0.
# - Penganut agama Kristen paling banyak berada di cluster 1 dan paling sedikit berada di cluster 0.
# - Penganut agama Katolik paling banyak berada di cluster 1 dan paling sedikit berada di cluster 2.
# - Penganut agama Hindu paling banyak berada di cluster 1 dan paling sedikit berada di cluster 0.
# - Penganut agama Budha paling banyak berada di cluster 0 dan paling sedikit berada di cluster 1.
# - Penganut agama Konghucu paling banyak berada di cluster 0 dan paling sedikit berada di cluster 1.
# - Penganut agama Kepercayaan paling banyak berada di cluster 0 dan paling sedikit berada di cluster 1.
